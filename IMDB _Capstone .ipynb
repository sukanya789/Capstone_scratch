# %% [markdown]
# # Project Overview

# %% [markdown]
# Introduction:
#
# The provided task involves web scraping, data storage in CSV files, creation of tables in SQLite database, executing SQL queries on the table, and performing similar queries using Pandas SQL on the loaded CSV data.
#
# The first CSV file includes the data like - Sno, Movie Name, Director Name(bifurcated into subfields as per number of directors in the movie), Duration, Year, Ratings, and Metascore.
# The second CSV file includes the data like - Movie Name, Stars(bifurcated into 4 subfields as per number of stars in the movie), Votes, Genere(bifurcated into 3 subfields as per the number of genere movie belongs), Gross Collection, Popularity, and Certification.
# The above task of project will be the phase1.
#
# Now for phase2: Here, two tables will be created in SQLite database using the columns provided in the CSV files. The data from each CSV file is gonna inserted into the corresponding tables. The subsequent SQL queries are executed on the tables in the SQLite database.
# The queries involve retrieving specific details from the tables based on various conditions and sorting orders.
#
# The CSV data is then loaded into Pandas DataFrames. The DataFrames are then used to execute Pandas SQL queries, which involve SQL-like operations on the DataFrames. The queries may include joins, filtering, sorting, and other operations as required. The results of the queries are obtained as Dataframes, which can be used for further analysis and visualization.

# %% [markdown]
# # 1

# %%
# Importing necessary libraries

import pandas as pd
import requests
from bs4 import BeautifulSoup
import pdb
import re
import csv

# %%
# Scrap the IMDB data and return a list of dictionaries
def scrape_imdb_data(page_num):
    url = f"https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1&start={(page_num - 1) * 50 + 1}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    movie_list = []
    
    for movie in soup.find_all("div", class_ = "lister-item mode-advanced"):
        title = movie.h3.a.text
        director_and_stars = movie.find("p", class_ = "").text.strip()
        director_start = director_and_stars.find("Director:") + len("Director:")
        director_end = director_and_stars.find("|", director_start)
        director_names = [name.strip() for name in director_and_stars[director_start:director_end].split(",")]
        # Bifurcate director field in three subfield
        director1 = director_names[0] if director_names else None
        director2 = director_names[1] if len(director_names) > 1 else None
        director3 = director_names[2] if len(director_names) > 2 else None
        duration = movie.find("span", class_ = "runtime").text if movie.find("span", class_ = "runtime") else ""
        year = movie.find("span", class_ = "lister-item-year").text.strip("()")
        rating = movie.find("div", class_ = "inline-block ratings-imdb-rating").strong.text
        metascore = movie.find("span", class_ = "metascore").text.strip() if movie.find("span", class_ = "metascore") else ""
        stars_start = director_and_stars.find("Stars:") + len("Stars:")
        stars = director_and_stars[stars_start:].strip().split(",")
        # Bifurcate the stars field into four subfields
        star1 = stars[0] if stars else None
        star2 = stars[1] if len(stars) > 1 else None
        star3 = stars[2] if len(stars) > 2 else None
        star4 = stars[3] if len(stars) > 3 else None
        votes_element = movie.find("p", class_ = "sort-num_votes-visible")
        votes = votes_element.find_all("span")[1].text.strip().replace(",","") if votes_element else ""
        genre_element = movie.find("span", class_ = "genre")
        genre = genre_element.text.strip().replace("\n", "") if genre_element else ""
        genres = [genre.strip() for genre in genre.split(",")]
        # bifurcate the  genre field to three subfields
        genre1 = genres[0] if genres else None
        genre2 = genres[1] if len(genres) > 1 else None
        genre3 = genres[2] if len(genres) > 2 else None
        gross_element = movie.find("span", text= re.compile("Gross:"))
        if gross_element and gross_element.find_next_sibling("span"):
            gross = gross_element.find_next_sibling("span").text.strip() if gross_element else ""
        else:
            gross = ""
        popularity_element = movie.find("span", class_ = "lister-item-index unbold text-primary")
        popularity = popularity_element.text.strip() if popularity_element else ""  
        certification_element = movie.find("span", class_ = "certificate")
        certification = certification_element.text.strip() if certification_element else ""
        
        movie_data = {"Sno": len(movie_list) + 1,
                     "Movie Name": title,
                     "Director1": director1,
                     "Director2": director2,
                     "Director3": director3,
                     "Duration": duration,
                     "Year": year,
                     "Rating": rating,
                     "Metascore": metascore,
                     "Star1": star1,
                     "Star2": star2,
                     "Star3": star3,
                     "Star4": star4,
                     "Votes": votes,
                     "Genre1": genre1,
                     "Genre2": genre2,
                     "Genre3": genre3,
                     "Gross collection": gross,
                     "Popularity": popularity,
                     "Certification": certification}
        movie_list.append(movie_data)
    return movie_list   

# Function to store data into two seperate CSV files
def store_data_in_csv(movie_list):
    with open("movies_directors.csv", mode = "w", newline = "", encoding = "utf-8") as df1:
        writer = csv.DictWriter(df1, fieldnames = ["Sno", "Movie Name", "Director1", "Director2", "Director3", "Duration", "Year", "Rating", "Metascore"])
        writer.writeheader()
        
        for index, movie in enumerate(movie_list, start = 1):
            writer.writerow({"Sno": index,
                            "Movie Name": movie["Movie Name"],
                            "Director1": movie["Director1"],
                            "Director2": movie["Director2"],
                            "Director3": movie["Director3"],
                            "Duration": movie["Duration"],
                            "Year": movie["Year"],
                            "Rating": movie["Rating"],
                            "Metascore": movie["Metascore"]})
            
    with open("movies_genres.csv", mode = "w", newline = "", encoding = "utf-8") as df2:
        writer = csv.DictWriter(df2, fieldnames = ["Movie Name", "Star1", "Star2", "Star3", "Star4", "Votes", "Genre1", "Genre2", "Genre3", "Gross collection", "Popularity", "Certification"])
        writer.writeheader() 
        
        for movie in movie_list:
            writer.writerow({"Movie Name": movie["Movie Name"],
                            "Star1": movie["Star1"],
                            "Star2": movie["Star2"],
                            "Star3": movie["Star3"],
                            "Star4": movie["Star4"],
                            "Votes": movie["Votes"],
                            "Genre1": movie["Genre1"],
                            "Genre2": movie["Genre2"],
                            "Genre3": movie["Genre3"],
                            "Gross collection": movie["Gross collection"],
                            "Popularity": movie["Popularity"],
                            "Certification": movie["Certification"]})
if __name__ == "__main__":
    all_movie_data = []
    
    # Loop through all pages and append data to the all_movie_data list.
    for page_num in range(1,38):
        movie_data = scrape_imdb_data(page_num)
        all_movie_data.extend(movie_data)
    store_data_in_csv(all_movie_data)    
    print("Data has been successfully scraped and stored in CSV files.")
# Out:
# Data has been successfully scraped and stored in CSV files.

# %%
df1 = pd.read_csv("movies_directors.csv")
df1
# Out:
#        Sno                                         Movie Name  \
# 0        1                                    The Dark Knight
# 1        2      The Lord of the Rings: The Return of the King
# 2        3                Spider-Man: Across the Spider-Verse
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1765  1766                                              Radhe
# 1766  1767                                             Race 3
# 1767  1768                                  Angels Apocalypse
# 1768  1769                                           Elk*rtuk
# 1769  1770                                            Sadak 2
#
#                    Director1      Director2           Director3 Duration  \
# 0          Christopher Nolan            NaN                 NaN  152 min
# 1              Peter Jackson            NaN                 NaN  201 min
# 2     s:\nJoaquim Dos Santos    Kemp Powers  Justin K. Thompson  140 min
# 3          Christopher Nolan            NaN                 NaN  148 min
# 4              Peter Jackson            NaN                 NaN  178 min
# ...                      ...            ...                 ...      ...
# 1765             Prabhu Deva            NaN                 NaN  109 min
# 1766            Remo D'Souza            NaN                 NaN  160 min
# 1767           s:\nSean Cain  Enzo Zelocchi                 NaN   85 min
# 1768           Keith English            NaN                 NaN  125 min
# 1769            Mahesh Bhatt            NaN                 NaN  133 min
#
#       Year  Rating  Metascore
# 0     2008     9.0       84.0
# 1     2003     9.0       94.0
# 2     2023     8.9       86.0
# 3     2010     8.8       74.0
# 4     2001     8.8       92.0
# ...    ...     ...        ...
# 1765  2021     1.9        NaN
# 1766  2018     1.9        NaN
# 1767  2015     1.6        NaN
# 1768  2021     1.5        NaN
# 1769  2020     1.2        NaN
#
# [1770 rows x 9 columns]

# %%
df2 = pd.read_csv("movies_genres.csv")
df2
# Out:
#                                              Movie Name              Star1  \
# 0                                       The Dark Knight     Christian Bale
# 1         The Lord of the Rings: The Return of the King        Elijah Wood
# 2                   Spider-Man: Across the Spider-Verse      Shameik Moore
# 3                                             Inception  Leonardo DiCaprio
# 4     The Lord of the Rings: The Fellowship of the Ring        Elijah Wood
# ...                                                 ...                ...
# 1765                                              Radhe        Salman Khan
# 1766                                             Race 3        Anil Kapoor
# 1767                                  Angels Apocalypse      Enzo Zelocchi
# 1768                                           Elk*rtuk  Vivianne Bánovits
# 1769                                            Sadak 2         Alia Bhatt
#
#                         Star2                 Star3                    Star4  \
# 0              \nHeath Ledger       \nAaron Eckhart          \nMichael Caine
# 1           \nViggo Mortensen        \nIan McKellen          \nOrlando Bloom
# 2          \nHailee Steinfeld   \nBrian Tyree Henry      \nLuna Lauren Velez
# 3      \nJoseph Gordon-Levitt         \nElliot Page           \nKen Watanabe
# 4              \nIan McKellen       \nOrlando Bloom              \nSean Bean
# ...                       ...                   ...                      ...
# 1765           \nDisha Patani       \nRandeep Hooda          \nJackie Shroff
# 1766            \nSalman Khan          \nBobby Deol   \nJacqueline Fernandez
# 1767          \nJana Rochelle   \nRyan C.F. Buckley        \nWilliam Kirkham
# 1768           \nAndrás Mózes         \nBarna Bokor        \nGabriella Gubás
# 1769            \nPooja Bhatt   \nAditya Roy Kapoor            \nSanjay Dutt
#
#         Votes     Genre1     Genre2     Genre3 Gross collection Popularity  \
# 0     2742002     Action      Crime      Drama         $534.86M         1.
# 1     1899372     Action  Adventure      Drama         $377.85M         2.
# 2      186672  Animation     Action  Adventure              NaN         3.
# 3     2433238     Action  Adventure     Sci-Fi         $292.58M         4.
# 4     1927794     Action  Adventure      Drama         $315.54M         5.
# ...       ...        ...        ...        ...              ...        ...
# 1765   179060     Action      Crime   Thriller              NaN     1,766.
# 1766    47815     Action      Crime   Thriller           $1.69M     1,767.
# 1767    42919     Action    Fantasy     Sci-Fi              NaN     1,768.
# 1768    39601     Action      Crime      Drama              NaN     1,769.
# 1769    96354     Action      Drama        NaN              NaN     1,770.
#
#      Certification
# 0               UA
# 1                U
# 2                U
# 3               UA
# 4                U
# ...            ...
# 1765            UA
# 1766            UA
# 1767           NaN
# 1768           NaN
# 1769           15+
#
# [1770 rows x 12 columns]

# %% [markdown]
# # 2

# %% [markdown]
# Now we will create two tables in SQLite and insert the data from the CSV files into the tables

# %%
import sqlite3

# Create a connection to the SQLite database
conn = sqlite3.connect("movies.db")

# Create Table 1
conn.execute(""" 
CREATE TABLE IF NOT EXISTS Table1(
     Sno INTEGER PRIMARY KEY AUTOINCREMENT,
     MovieName TEXT,
     Director1 TEXT,
     Director2 TEXT,
     Director3 TEXT,
     Duration TEXT,
     Year INTEGER,
     Rating REAL,
     Metascore REAL)""")

# Insert data into Table 1
df1 = pd.read_csv("movies_directors.csv")
df1.to_sql("Table1", conn, if_exists = "replace", index = False)

# Table 2
conn.execute("""
CREATE TABLE IF NOT EXISTS Table2(
     MovieName TEXT,
     Star1 TEXT,
     Star2 TEXT,
     Star3 TEXT,
     Star4 TEXT,
     Votes INTEGER,
     Genre1 TEXT,
     Genre2 TEXT,
     Genre3 TEXT,
     GrossCollection REAL,
     Popularity INTEGER,
     Certification TEXT)""")

# Insert data
df2 = pd.read_csv("movies_genres.csv")
df2.to_sql("Table2", conn, if_exists = "replace", index = False)

# Commit and close the database connection
conn.commit()
conn.close()

# %% [markdown]
# * Now we will start quering the tables using SQL queries

# %%
# Lets establish a new connection to the SQLite database
conn = sqlite3.connect("movies.db")

# Queries for table 1

# 1. Let's Display all the details of movies created by directors Christopher and Matt Reeves.
query1 = """
SELECT * FROM Table1
WHERE Director1 LIKE "%Christopher%" OR Director1 LIKE "%Matt Reeves%"
   OR Director2 LIKE "%Christopher%" OR Director2 LIKE "%Matt Reeves%"
   OR Director3 LIKE "%Christopher%" OR Director3 LIKE "%Matt Reeves%"
"""
result1 = pd.read_sql_query(query1, conn)
print("Query 1:")
print(result1)
print()

# 2. Display all the details of movies with a duration of 140 to 190 minutes.
query2 = """
SELECT * FROM Table1
WHERE Duration >=140 AND Duration <=190"""

result2 = pd.read_sql_query(query2, conn)
print("Query 2:")
print(result2)
print()

# 3. Display all details of movies with ratings above 7 in ascending order.
query3 = """
SELECT * FROM Table1
WHERE Rating > 7
ORDER BY Rating ASC"""

result3 = pd.read_sql_query(query3, conn)
print("Query 3:")
print(result3)
print()

# 4. Display all movie names in descending order.
query4 = """
SELECT DISTINCT `Movie Name` FROM Table1
ORDER BY `Movie Name` DESC"""

result4 = pd.read_sql_query(query4, conn)
print("Query 4:")
print(result4)
print()

# 5. Display movie name starts with 'P' and their rating is greater than 7.
query5 = """
SELECT `Movie Name` FROM Table1
WHERE `Movie Name` LIKE 'P%' AND Rating > 7"""

result5 = pd.read_sql_query(query5, conn)
print("Query 5:")
print(result5)
print()
# Out:
# Query 1:
#      Sno                                     Movie Name  \
# 0      1                                The Dark Knight
# 1      4                                      Inception
# 2     22                          The Dark Knight Rises
# 3     40                                  Batman Begins
# 4     57  Mission: Impossible - Dead Reckoning Part One
# 5    132                                     The Batman
# 6    133                                        Dunkirk
# 7    167                  Mission: Impossible - Fallout
# 8    175                                 The Lego Movie
# 9    231                 Dawn of the Planet of the Apes
# 10   289             Mission: Impossible - Rogue Nation
# 11   310                 War for the Planet of the Apes
# 12   323                                          Tenet
# 13   386                                 21 Jump Street
# 14   500                                   Jack Reacher
# 15   517                                    Cloverfield
# 16   527                                 22 Jump Street
# 17   656                                     Young Guns
# 18   789                             The Way of the Gun
# 19   988                                    Black Death
# 20  1048          Scouts Guide to the Zombie Apocalypse
# 21  1714                            The Next Karate Kid
#
#                 Director1           Director2 Director3 Duration  Year  \
# 0       Christopher Nolan                None      None  152 min  2008
# 1       Christopher Nolan                None      None  148 min  2010
# 2       Christopher Nolan                None      None  164 min  2012
# 3       Christopher Nolan                None      None  140 min  2005
# 4   Christopher McQuarrie                None      None  163 min  2023
# 5             Matt Reeves                None      None  176 min  2022
# 6       Christopher Nolan                None      None  106 min  2017
# 7   Christopher McQuarrie                None      None  147 min  2018
# 8           s:\nPhil Lord  Christopher Miller      None  100 min  2014
# 9             Matt Reeves                None      None  130 min  2014
# 10  Christopher McQuarrie                None      None  131 min  2015
# 11            Matt Reeves                None      None  140 min  2017
# 12      Christopher Nolan                None      None  150 min  2020
# 13          s:\nPhil Lord  Christopher Miller      None  109 min  2012
# 14  Christopher McQuarrie                None      None  130 min  2012
# 15            Matt Reeves                None      None   85 min  2008
# 16          s:\nPhil Lord  Christopher Miller      None  112 min  2014
# 17       Christopher Cain                None      None  107 min  1988
# 18  Christopher McQuarrie                None      None  119 min  2000
# 19      Christopher Smith                None      None  102 min  2010
# 20     Christopher Landon                None      None   93 min  2015
# 21       Christopher Cain                None      None  107 min  1994
#
#     Rating  Metascore
# 0      9.0       84.0
# 1      8.8       74.0
# 2      8.4       78.0
# 3      8.2       70.0
# 4      8.1       81.0
# 5      7.8       72.0
# 6      7.8       94.0
# 7      7.7       86.0
# 8      7.7       83.0
# 9      7.6       79.0
# 10     7.4       75.0
# 11     7.4       82.0
# 12     7.3       69.0
# 13     7.2       69.0
# 14     7.0       50.0
# 15     7.0       64.0
# 16     7.0       71.0
# 17     6.8       50.0
# 18     6.6       49.0
# 19     6.4       71.0
# 20     6.3       32.0
# 21     4.5       36.0
#
# Query 2:
#       Sno                                         Movie Name  \
# 0       1                                    The Dark Knight
# 1       3                Spider-Man: Across the Spider-Verse
# 2       4                                          Inception
# 3       5  The Lord of the Rings: The Fellowship of the Ring
# 4       6              The Lord of the Rings: The Two Towers
# ..    ...                                                ...
# 203  1757                                              Liger
# 204  1758                                             Gunday
# 205  1761                                             Laxmii
# 206  1762                                        Heropanti 2
# 207  1767                                             Race 3
#
#                   Director1            Director2           Director3 Duration  \
# 0         Christopher Nolan                 None                None  152 min
# 1    s:\nJoaquim Dos Santos          Kemp Powers  Justin K. Thompson  140 min
# 2         Christopher Nolan                 None                None  148 min
# 3             Peter Jackson                 None                None  178 min
# 4             Peter Jackson                 None                None  179 min
# ..                      ...                  ...                 ...      ...
# 203          Puri Jagannadh                 None                None  140 min
# 204         Ali Abbas Zafar                 None                None  152 min
# 205    s:\nRaghava Lawrence  Balakrishnan Thevar                None  141 min
# 206              Ahmed Khan                 None                None  145 min
# 207            Remo D'Souza                 None                None  160 min
#
#      Year  Rating  Metascore
# 0    2008     9.0       84.0
# 1    2023     8.9       86.0
# 2    2010     8.8       74.0
# 3    2001     8.8       92.0
# 4    2002     8.8       87.0
# ..    ...     ...        ...
# 203  2022     2.7        NaN
# 204  2014     2.7        NaN
# 205  2020     2.5        NaN
# 206  2022     2.5        NaN
# 207  2018     1.9        NaN
#
# [208 rows x 9 columns]
#
# Query 3:
#      Sno                                         Movie Name  \
# 0    433                                Mission: Impossible
# 1    434                                       Extraction 2
# 2    435                                          The Mummy
# 3    436                                       Man of Steel
# 4    437                                               Prey
# ..   ...                                                ...
# 489    5  The Lord of the Rings: The Fellowship of the Ring
# 490    6              The Lord of the Rings: The Two Towers
# 491    3                Spider-Man: Across the Spider-Verse
# 492    1                                    The Dark Knight
# 493    2      The Lord of the Rings: The Return of the King
#
#                   Director1    Director2           Director3 Duration  \
# 0            Brian De Palma         None                None  110 min
# 1              Sam Hargrave         None                None  122 min
# 2           Stephen Sommers         None                None  124 min
# 3               Zack Snyder         None                None  143 min
# 4          Dan Trachtenberg         None                None  100 min
# ..                      ...          ...                 ...      ...
# 489           Peter Jackson         None                None  178 min
# 490           Peter Jackson         None                None  179 min
# 491  s:\nJoaquim Dos Santos  Kemp Powers  Justin K. Thompson  140 min
# 492       Christopher Nolan         None                None  152 min
# 493           Peter Jackson         None                None  201 min
#
#          Year  Rating  Metascore
# 0        1996     7.1       59.0
# 1        2023     7.1       57.0
# 2        1999     7.1       48.0
# 3        2013     7.1       55.0
# 4    I) (2022     7.1       71.0
# ..        ...     ...        ...
# 489      2001     8.8       92.0
# 490      2002     8.8       87.0
# 491      2023     8.9       86.0
# 492      2008     9.0       84.0
# 493      2003     9.0       94.0
#
# [494 rows x 9 columns]
#
# Query 4:
#                       Movie Name
# 0                   Ölümlü Dünya
# 1                       Æon Flux
# 2        xXx: State of the Union
# 3     xXx: Return of Xander Cage
# 4                            xXx
# ...                          ...
# 1734                   12 Rounds
# 1735                   10,000 BC
# 1736             1 - Nenokkadine
# 1737                         '71
# 1738                   #Saraitda
#
# [1739 rows x 1 columns]
#
# Query 5:
#                                            Movie Name
# 0                                    Paan Singh Tomar
# 1   Pirates of the Caribbean: The Curse of the Bla...
# 2                             Per un pugno di dollari
# 3                                            Predator
# 4                                  Ponniyin Selvan: I
# 5                           Pushpa: The Rise - Part 1
# 6                                      Predestination
# 7          Pirates of the Caribbean: Dead Man's Chest
# 8                                        Patriots Day
# 9                                         Point Break
# 10                                               Prey
# 11           Pirates of the Caribbean: At World's End
# 12                                            Payback

# %%
# Queries for table 2

# 1. Display all movie names with star 'Arnold Schwarzenegger' in ascending order.

query6 = """
SELECT  DISTINCT `Movie Name` FROM Table2
WHERE (`Star1` LIKE '%Arnold Schwarzenegger%')
   OR (`Star2` LIKE '%Arnold Schwarzenegger%') 
   OR (`Star3` LIKE '%Arnold Schwarzenegger%')
   OR (`Star4` LIKE '%Arnold Schwarzenegger%')
ORDER BY `Movie Name` ASC"""

result6 = pd.read_sql_query(query6, conn)
print("Query 6:")
print(result6)
print()


# 2. Now display all details of the movie with the highest number of votes.
query7 = """
SELECT * FROM Table2
WHERE Votes = (SELECT MAX(Votes) FROM Table2)
LIMIT 1 """

result7 = pd.read_sql_query(query7, conn)
print("Query 7:")
print(result7)
print()

# 3. Now display  movie names with gross colletion in descending order.
query8 = """
SELECT DISTINCT `Movie Name` FROM Table2
ORDER BY `Gross collection` DESC"""

result8 = pd.read_sql_query(query8, conn)
print("Query8:")
print(result8)
print()

# 4. Display the gross collection of movies with the star 'Arnold'.
query9 = """
SELECT DISTINCT `Movie Name`, `Gross collection` FROM Table2
WHERE (`Star1` LIKE '%Arnold%')
   OR (`Star2` LIKE '%Arnold')
   OR (`Star3` LIKE '%Arnold')
   OR (`Star4` LIKE '%Arnold')"""

result9 = pd.read_sql_query(query9, conn)
print("Query 9:")
print(result9)
print()

# 5. Dispaly all details of movies with comedy and action genres.
query10 = """
SELECT * FROM Table2
WHERE (`Genre1` LIKE '%Comedy%' AND `Genre2` LIKE '%Action%')
   OR (`Genre1` LIKE '%Action%' AND `Genre2` LIKE '%Comedy%')
   OR (`Genre1` LIKE '%Comedy%' AND `Genre3` LIKE '%Action%')
   OR (`Genre1` LIKE '%Action%' AND `Genre3` LIKE '%Comedy%')
   OR (`Genre2` LIKE '%Comedy%' AND `Genre3` LIKE '%Action%')
   OR (`Genre2` LIKE '%Action%' AND `Genre3` LIKE '%Comedy%')"""

result10 = pd.read_sql_query(query10, conn)
print("Query10:")
print(result10)
print()
# Out:
# Query 6:
#                             Movie Name
# 0                       Batman & Robin
# 1                    Collateral Damage
# 2                             Commando
# 3                  Conan the Barbarian
# 4                  Conan the Destroyer
# 5                          End of Days
# 6                               Eraser
# 7                          Escape Plan
# 8                     Kindergarten Cop
# 9                     Last Action Hero
# 10                            Predator
# 11                            Raw Deal
# 12                            Red Heat
# 13                           Red Sonja
# 14                            Sabotage
# 15          Terminator 2: Judgment Day
# 16  Terminator 3: Rise of the Machines
# 17                  Terminator Genisys
# 18               Terminator: Dark Fate
# 19                         The 6th Day
# 20                      The Last Stand
# 21                     The Running Man
# 22                      The Terminator
# 23                        Total Recall
# 24                           True Lies
#
# Query 7:
#         Movie Name           Star1            Star2             Star3  \
# 0  The Dark Knight  Christian Bale   \nHeath Ledger   \nAaron Eckhart
#
#               Star4    Votes  Genre1 Genre2 Genre3 Gross collection  \
# 0   \nMichael Caine  2742002  Action  Crime  Drama         $534.86M
#
#   Popularity Certification
# 0         1.            UA
#
# Query8:
#               Movie Name
# 0     Olympus Has Fallen
# 1       The Green Hornet
# 2       Inspector Gadget
# 3         Public Enemies
# 4        The Book of Eli
# ...                  ...
# 1734       The Prototype
# 1735               Radhe
# 1736   Angels Apocalypse
# 1737            Elk*rtuk
# 1738             Sadak 2
#
# [1739 rows x 1 columns]
#
# Query 9:
#                             Movie Name Gross collection
# 0           Terminator 2: Judgment Day         $204.84M
# 1                       The Terminator          $38.40M
# 2                             Predator          $59.74M
# 3                         Total Recall         $119.39M
# 4                            True Lies         $146.28M
# 5                  Conan the Barbarian          $39.57M
# 6                             Commando          $35.10M
# 7                      The Running Man          $38.12M
# 8                     Last Action Hero          $50.02M
# 9   Terminator 3: Rise of the Machines         $150.37M
# 10                  Terminator Genisys          $89.76M
# 11                      The Last Stand          $12.05M
# 12                    Kindergarten Cop          $91.46M
# 13                              Eraser         $101.30M
# 14                            Red Heat          $34.99M
# 15                 Conan the Destroyer          $31.04M
# 16                         The 6th Day          $34.60M
# 17                         End of Days          $66.89M
# 18                            Sabotage          $10.51M
# 19                            Raw Deal          $16.21M
# 20                   Collateral Damage          $40.08M
# 21                           Red Sonja           $6.95M
# 22                      Batman & Robin         $107.33M
#
# Query10:
#                                       Movie Name           Star1  \
# 0                             Gangs of Wasseypur  Manoj Bajpayee
# 1                                   Sherlock Jr.   Buster Keaton
# 2                 Guardians of the Galaxy Vol. 3     Chris Pratt
# 3            Lock, Stock and Two Smoking Barrels   Jason Flemyng
# 4                              Bajrangi Bhaijaan     Salman Khan
# ..                                           ...             ...
# 367                 The Adventures of Pluto Nash    Eddie Murphy
# 368  The Adventures of Sharkboy and Lavagirl 3-D     Cayden Boyd
# 369        Spy Kids 4: All the Time in the World    Jessica Alba
# 370                                       Laxmii    Akshay Kumar
# 371                                  Heropanti 2    Tiger Shroff
#
#                       Star2                   Star3                 Star4  \
# 0     \nNawazuddin Siddiqui      \nTigmanshu Dhulia        \nRicha Chadha
# 1         \nKathryn McGuire            \nJoe Keaton      \nErwin Connelly
# 2          \nChukwudi Iwuji        \nBradley Cooper     \nPom Klementieff
# 3         \nDexter Fletcher            \nNick Moran       \nJason Statham
# 4      \nHarshaali Malhotra   \nNawazuddin Siddiqui      \nKareena Kapoor
# ..                      ...                     ...                   ...
# 367              \nJay Mohr           \nRandy Quaid      \nRosario Dawson
# 368          \nGeorge Lopez         \nKristin Davis      \nDavid Arquette
# 369          \nJeremy Piven           \nJoel McHale     \nRowan Blanchard
# 370          \nKiara Advani         \nSharad Kelkar    \nAshwini Kalsekar
# 371   \nNawazuddin Siddiqui          \nTara Sutaria   \nAmber Doig-Thorne
#
#       Votes  Genre1     Genre2   Genre3 Gross collection Popularity  \
# 0     99915  Action     Comedy    Crime             None        47.
# 1     53155  Action     Comedy  Romance           $0.98M        52.
# 2    221677  Action  Adventure   Comedy             None        59.
# 3    598142  Action     Comedy    Crime           $3.90M        69.
# 4     92713  Action  Adventure   Comedy           $8.18M        72.
# ..      ...     ...        ...      ...              ...        ...
# 367   26542  Action     Comedy   Sci-Fi           $4.42M     1,740.
# 368   40313  Action  Adventure   Comedy          $39.18M     1,744.
# 369   27180  Action  Adventure   Comedy          $38.54M     1,750.
# 370   58142  Action     Comedy   Horror             None     1,761.
# 371   27063  Action     Comedy    Crime             None     1,762.
#
#     Certification
# 0               A
# 1            None
# 2              UA
# 3               A
# 4              UA
# ..            ...
# 367         PG-13
# 368             U
# 369            PG
# 370        UA 16+
# 371            UA
#
# [372 rows x 12 columns]

# %%
# Subqueries

# 1. Display all details from both tables where movie names are the same
query11 = """
SELECT DISTINCT * FROM Table1
JOIN Table2 ON Table1.`Movie Name` = Table2.`Movie Name` """

result11 = pd.read_sql_query(query11, conn)
print("Query11:")
print(result11)
print()

# 2. Let's display all movie names, Director, ratings, and gross collection where the genre is action.
query12 = """
SELECT DISTINCT Table1.`Movie Name`, Table1. `Director1`, Table1. `Director2`, Table1. `Director3`, Table1. `Rating`, Table2.`Gross collection`
FROM Table1
JOIN Table2 ON Table1.`Movie Name` = Table2.`Movie Name`
WHERE Table2. `Genre1` LIKE '%Action%' OR Table2. `Genre2` LIKE '%Action%' OR Table2. `Genre3` LIKE '%Action%'"""

result12 = pd.read_sql_query(query12, conn)
print("Query12:")
print(result12)
print()

# 3. Now query will display all details from both the tables with the highest gross collection.
query13 = """
SELECT DISTINCT *
FROM Table1
JOIN Table2 ON Table1.`Movie Name` = Table2.`Movie Name`
WHERE Table2.`Gross collection` = (SELECT MAX(`Gross collection`) FROM Table2)"""

result13 = pd.read_sql_query(query13, conn)
print("Query13:")
print(result13)
print()


# 4. Now query will display all details from both the tables with the highest rating.
query14 = """SELECT DISTINCT *
FROM Table1
JOIN Table2 ON Table1. `Movie Name` = Table2.`Movie Name`
WHERE Table1.Rating = (SELECT MAX(Rating) FROM Table1)"""

result14 = pd.read_sql_query(query14, conn)
print("Query14:")
print(result14)
print()

# 5. This query will display all the details from both tables with the lowest gross collection and lowest rating.
query15 = """SELECT DISTINCT *
FROM Table1
JOIN Table2 ON Table1.`Movie Name` = Table2.`Movie Name`
WHERE Table1.Rating = (SELECT MIN(Rating) AS MinRating FROM Table1)
 AND Table2.`Gross collection` = (SELECT MIN(`Gross collection`) AS MinGross FROM Table2)"""

result15 = pd.read_sql_query(query15, conn)
print("Query15:")
print(result15)
print()
# Out:
# Query11:
#        Sno                                         Movie Name  \
# 0        1                                    The Dark Knight
# 1        2      The Lord of the Rings: The Return of the King
# 2        3                Spider-Man: Across the Spider-Verse
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1827  1766                                              Radhe
# 1828  1767                                             Race 3
# 1829  1768                                  Angels Apocalypse
# 1830  1769                                           Elk*rtuk
# 1831  1770                                            Sadak 2
#
#                    Director1      Director2           Director3 Duration  \
# 0          Christopher Nolan           None                None  152 min
# 1              Peter Jackson           None                None  201 min
# 2     s:\nJoaquim Dos Santos    Kemp Powers  Justin K. Thompson  140 min
# 3          Christopher Nolan           None                None  148 min
# 4              Peter Jackson           None                None  178 min
# ...                      ...            ...                 ...      ...
# 1827             Prabhu Deva           None                None  109 min
# 1828            Remo D'Souza           None                None  160 min
# 1829           s:\nSean Cain  Enzo Zelocchi                None   85 min
# 1830           Keith English           None                None  125 min
# 1831            Mahesh Bhatt           None                None  133 min
#
#       Year  Rating  Metascore  \
# 0     2008     9.0       84.0
# 1     2003     9.0       94.0
# 2     2023     8.9       86.0
# 3     2010     8.8       74.0
# 4     2001     8.8       92.0
# ...    ...     ...        ...
# 1827  2021     1.9        NaN
# 1828  2018     1.9        NaN
# 1829  2015     1.6        NaN
# 1830  2021     1.5        NaN
# 1831  2020     1.2        NaN
#
#                                              Movie Name  ...  \
# 0                                       The Dark Knight  ...
# 1         The Lord of the Rings: The Return of the King  ...
# 2                   Spider-Man: Across the Spider-Verse  ...
# 3                                             Inception  ...
# 4     The Lord of the Rings: The Fellowship of the Ring  ...
# ...                                                 ...  ...
# 1827                                              Radhe  ...
# 1828                                             Race 3  ...
# 1829                                  Angels Apocalypse  ...
# 1830                                           Elk*rtuk  ...
# 1831                                            Sadak 2  ...
#
#                         Star2                 Star3                    Star4  \
# 0              \nHeath Ledger       \nAaron Eckhart          \nMichael Caine
# 1           \nViggo Mortensen        \nIan McKellen          \nOrlando Bloom
# 2          \nHailee Steinfeld   \nBrian Tyree Henry      \nLuna Lauren Velez
# 3      \nJoseph Gordon-Levitt         \nElliot Page           \nKen Watanabe
# 4              \nIan McKellen       \nOrlando Bloom              \nSean Bean
# ...                       ...                   ...                      ...
# 1827           \nDisha Patani       \nRandeep Hooda          \nJackie Shroff
# 1828            \nSalman Khan          \nBobby Deol   \nJacqueline Fernandez
# 1829          \nJana Rochelle   \nRyan C.F. Buckley        \nWilliam Kirkham
# 1830           \nAndrás Mózes         \nBarna Bokor        \nGabriella Gubás
# 1831            \nPooja Bhatt   \nAditya Roy Kapoor            \nSanjay Dutt
#
#         Votes     Genre1     Genre2     Genre3 Gross collection Popularity  \
# 0     2742002     Action      Crime      Drama         $534.86M         1.
# 1     1899372     Action  Adventure      Drama         $377.85M         2.
# 2      186672  Animation     Action  Adventure             None         3.
# 3     2433238     Action  Adventure     Sci-Fi         $292.58M         4.
# 4     1927794     Action  Adventure      Drama         $315.54M         5.
# ...       ...        ...        ...        ...              ...        ...
# 1827   179060     Action      Crime   Thriller             None     1,766.
# 1828    47815     Action      Crime   Thriller           $1.69M     1,767.
# 1829    42919     Action    Fantasy     Sci-Fi             None     1,768.
# 1830    39601     Action      Crime      Drama             None     1,769.
# 1831    96354     Action      Drama       None             None     1,770.
#
#      Certification
# 0               UA
# 1                U
# 2                U
# 3               UA
# 4                U
# ...            ...
# 1827            UA
# 1828            UA
# 1829          None
# 1830          None
# 1831           15+
#
# [1832 rows x 21 columns]
#
# Query12:
#                                              Movie Name  \
# 0                                       The Dark Knight
# 1         The Lord of the Rings: The Return of the King
# 2                   Spider-Man: Across the Spider-Verse
# 3                                             Inception
# 4     The Lord of the Rings: The Fellowship of the Ring
# ...                                                 ...
# 1827                                              Radhe
# 1828                                             Race 3
# 1829                                  Angels Apocalypse
# 1830                                           Elk*rtuk
# 1831                                            Sadak 2
#
#                    Director1      Director2           Director3  Rating  \
# 0          Christopher Nolan           None                None     9.0
# 1              Peter Jackson           None                None     9.0
# 2     s:\nJoaquim Dos Santos    Kemp Powers  Justin K. Thompson     8.9
# 3          Christopher Nolan           None                None     8.8
# 4              Peter Jackson           None                None     8.8
# ...                      ...            ...                 ...     ...
# 1827             Prabhu Deva           None                None     1.9
# 1828            Remo D'Souza           None                None     1.9
# 1829           s:\nSean Cain  Enzo Zelocchi                None     1.6
# 1830           Keith English           None                None     1.5
# 1831            Mahesh Bhatt           None                None     1.2
#
#      Gross collection
# 0            $534.86M
# 1            $377.85M
# 2                None
# 3            $292.58M
# 4            $315.54M
# ...               ...
# 1827             None
# 1828           $1.69M
# 1829             None
# 1830             None
# 1831             None
#
# [1832 rows x 6 columns]
#
# Query13:
#    Sno          Movie Name      Director1 Director2 Director3 Duration  Year  \
# 0  868  Olympus Has Fallen  Antoine Fuqua      None      None  119 min  2013
#
#    Rating  Metascore          Movie Name  ...             Star2  \
# 0     6.5       41.0  Olympus Has Fallen  ...   \nAaron Eckhart
#
#                Star3              Star4   Votes  Genre1    Genre2 Genre3  \
# 0   \nMorgan Freeman   \nAngela Bassett  284975  Action  Thriller   None
#
#   Gross collection Popularity Certification
# 0          $98.93M       868.             A
#
# [1 rows x 21 columns]
#
# Query14:
#    Sno                                     Movie Name          Director1  \
# 0    1                                The Dark Knight  Christopher Nolan
# 1    2  The Lord of the Rings: The Return of the King      Peter Jackson
#
#   Director2 Director3 Duration  Year  Rating  Metascore  \
# 0      None      None  152 min  2008     9.0       84.0
# 1      None      None  201 min  2003     9.0       94.0
#
#                                       Movie Name  ...               Star2  \
# 0                                The Dark Knight  ...      \nHeath Ledger
# 1  The Lord of the Rings: The Return of the King  ...   \nViggo Mortensen
#
#               Star3             Star4    Votes  Genre1     Genre2 Genre3  \
# 0   \nAaron Eckhart   \nMichael Caine  2742002  Action      Crime  Drama
# 1    \nIan McKellen   \nOrlando Bloom  1899372  Action  Adventure  Drama
#
#   Gross collection Popularity Certification
# 0         $534.86M         1.            UA
# 1         $377.85M         2.             U
#
# [2 rows x 21 columns]
#
# Query15:
# Empty DataFrame
# Columns: [Sno, Movie Name, Director1, Director2, Director3, Duration, Year, Rating, Metascore, Movie Name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross collection, Popularity, Certification]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Close the connection
conn.close()

# %% [markdown]
# * Now we will make solution of above all 15 query using Pandas SQL

# %%
! pip install pandasql
# Out:
# Requirement already satisfied: pandasql in /Applications/anaconda3/lib/python3.10/site-packages (0.7.3)
# Requirement already satisfied: numpy in /Applications/anaconda3/lib/python3.10/site-packages (from pandasql) (1.23.5)
# Requirement already satisfied: sqlalchemy in /Applications/anaconda3/lib/python3.10/site-packages (from pandasql) (1.4.39)
# Requirement already satisfied: pandas in /Applications/anaconda3/lib/python3.10/site-packages (from pandasql) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Applications/anaconda3/lib/python3.10/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Applications/anaconda3/lib/python3.10/site-packages (from pandas->pandasql) (2022.7)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)

# %%
from pandasql import sqldf

# Define pandasql function
pysqldf = lambda q: sqldf(q, globals())

# Load CSV files into dataframes
df1 = pd.read_csv("movies_directors.csv")
df2 = pd.read_csv("movies_genres.csv")

# Concatenate the dataframes for subqueries
df_new = pd.merge(df1, df2, on = 'Movie Name')

# %% [markdown]
# Queries' solution using Pandas SQL

# %%
# Q1
query1 = """SELECT * FROM df1
WHERE Director1 LIKE '%Christopher%' OR Director1 LIKE '%Matt Reeves%'
   OR Director1 LIKE '%Christopher%' OR Director1 LIKE '%Matt Reeves%'
   OR Director1 LIKE '%Christopher%' OR Director1 LIKE '%Matt Reeves%'"""

result1 = pysqldf(query1)
print("Query1:")
print(result1)
print()


# Q2
query2 = """SELECT *
FROM df1
WHERE Duration >= 140
AND Duration <= 190"""

result2 = pysqldf(query2)
print("Query 2:")
print(result2)
print()

# Q3
query3 = """SELECT *
FROM df1
WHERE Rating >7
ORDER BY Rating ASC"""

result3 = pysqldf(query3)
print("Query 3:")
print(result3)
print()

# Q4
query4 = """SELECT DISTINCT `Movie Name` FROM df1
ORDER BY `Movie Name` DESC"""

result4 = pysqldf(query4)
print("Query 4:")
print(result4)
print()

# Q5
query5 = """SELECT `Movie Name` FROM df1
WHERE `Movie Name` LIKE 'P%'
AND Rating>7 """

result5 = pysqldf(query5)
print("Query 5:")
print(result5)
print()

# Q6
query6 = """SELECT DISTINCT `Movie Name` FROM df2
WHERE Star1 LIKE '%Arnold Schwarzenegger%'
   OR Star2 LIKE '%Arnold Schwarzenegger%'
   OR Star3 LIKE '%Arnold Schwarzenegger%'
   OR Star4 LIKE '%Arnold Schwarzenegger%'
ORDER BY `Movie Name` ASC """

result6 = pysqldf(query6)
print("Query 6:")
print(result6)
print()

# Q7
query7 = """SELECT * FROM df2
WHERE Votes == (SELECT MAX(Votes) FROM df2)"""

result7 = pysqldf(query7)
print("Query 7:")
print(result7)
print()

# Q8
query8 = """SELECT DISTINCT `Movie Name` FROM df2
ORDER BY `Gross collection` DESC """

result8 = pysqldf(query8)
print("Query 8:")
print(result8)
print()

# Q9
query9 = """SELECT DISTINCT `Movie Name`, `Gross collection`
FROM df2 WHERE Star1 LIKE '%Arnold%'
            OR Star2 LIKE '%Arnold%'
            OR Star3 LIKE '%Arnold%'
            OR Star4 LIKE '%Arnold%'"""

result9 = pysqldf(query9)
print("Query 9 :")
print(result9)
print()

# Q10
query10 = """SELECT * FROM df2
WHERE Genre1 LIKE '%Comedy%' AND Genre2 LIKE '%Action%'
   OR Genre1 LIKE '%Action%' AND Genre2 LIKE '%Comedy%'
   OR Genre1 LIKE '%Comedy%' AND Genre3 LIKE '%Action%'
   OR Genre1 LIKE '%Action%' AND Genre3 LIKE '%Comedy%'
   OR Genre2 LIKE '%Comedy%' AND Genre3 LIKE '%Action%'
   OR Genre2 LIKE '%Action%' AND Genre3 LIKE '%Comedy%'"""

result10 = pysqldf(query10)
print("Query 10:")
print(result10)
print()
# Out:
# Query1:
#      Sno                                     Movie Name  \
# 0      1                                The Dark Knight
# 1      4                                      Inception
# 2     22                          The Dark Knight Rises
# 3     40                                  Batman Begins
# 4     57  Mission: Impossible - Dead Reckoning Part One
# 5    132                                     The Batman
# 6    133                                        Dunkirk
# 7    167                  Mission: Impossible - Fallout
# 8    231                 Dawn of the Planet of the Apes
# 9    289             Mission: Impossible - Rogue Nation
# 10   310                 War for the Planet of the Apes
# 11   323                                          Tenet
# 12   500                                   Jack Reacher
# 13   517                                    Cloverfield
# 14   656                                     Young Guns
# 15   789                             The Way of the Gun
# 16   988                                    Black Death
# 17  1048          Scouts Guide to the Zombie Apocalypse
# 18  1714                            The Next Karate Kid
#
#                 Director1 Director2 Director3 Duration  Year  Rating  \
# 0       Christopher Nolan      None      None  152 min  2008     9.0
# 1       Christopher Nolan      None      None  148 min  2010     8.8
# 2       Christopher Nolan      None      None  164 min  2012     8.4
# 3       Christopher Nolan      None      None  140 min  2005     8.2
# 4   Christopher McQuarrie      None      None  163 min  2023     8.1
# 5             Matt Reeves      None      None  176 min  2022     7.8
# 6       Christopher Nolan      None      None  106 min  2017     7.8
# 7   Christopher McQuarrie      None      None  147 min  2018     7.7
# 8             Matt Reeves      None      None  130 min  2014     7.6
# 9   Christopher McQuarrie      None      None  131 min  2015     7.4
# 10            Matt Reeves      None      None  140 min  2017     7.4
# 11      Christopher Nolan      None      None  150 min  2020     7.3
# 12  Christopher McQuarrie      None      None  130 min  2012     7.0
# 13            Matt Reeves      None      None   85 min  2008     7.0
# 14       Christopher Cain      None      None  107 min  1988     6.8
# 15  Christopher McQuarrie      None      None  119 min  2000     6.6
# 16      Christopher Smith      None      None  102 min  2010     6.4
# 17     Christopher Landon      None      None   93 min  2015     6.3
# 18       Christopher Cain      None      None  107 min  1994     4.5
#
#     Metascore
# 0        84.0
# 1        74.0
# 2        78.0
# 3        70.0
# 4        81.0
# 5        72.0
# 6        94.0
# 7        86.0
# 8        79.0
# 9        75.0
# 10       82.0
# 11       69.0
# 12       50.0
# 13       64.0
# 14       50.0
# 15       49.0
# 16       71.0
# 17       32.0
# 18       36.0
#
# Query 2:
#       Sno                                         Movie Name  \
# 0       1                                    The Dark Knight
# 1       3                Spider-Man: Across the Spider-Verse
# 2       4                                          Inception
# 3       5  The Lord of the Rings: The Fellowship of the Ring
# 4       6              The Lord of the Rings: The Two Towers
# ..    ...                                                ...
# 203  1757                                              Liger
# 204  1758                                             Gunday
# 205  1761                                             Laxmii
# 206  1762                                        Heropanti 2
# 207  1767                                             Race 3
#
#                   Director1            Director2           Director3 Duration  \
# 0         Christopher Nolan                 None                None  152 min
# 1    s:\nJoaquim Dos Santos          Kemp Powers  Justin K. Thompson  140 min
# 2         Christopher Nolan                 None                None  148 min
# 3             Peter Jackson                 None                None  178 min
# 4             Peter Jackson                 None                None  179 min
# ..                      ...                  ...                 ...      ...
# 203          Puri Jagannadh                 None                None  140 min
# 204         Ali Abbas Zafar                 None                None  152 min
# 205    s:\nRaghava Lawrence  Balakrishnan Thevar                None  141 min
# 206              Ahmed Khan                 None                None  145 min
# 207            Remo D'Souza                 None                None  160 min
#
#      Year  Rating  Metascore
# 0    2008     9.0       84.0
# 1    2023     8.9       86.0
# 2    2010     8.8       74.0
# 3    2001     8.8       92.0
# 4    2002     8.8       87.0
# ..    ...     ...        ...
# 203  2022     2.7        NaN
# 204  2014     2.7        NaN
# 205  2020     2.5        NaN
# 206  2022     2.5        NaN
# 207  2018     1.9        NaN
#
# [208 rows x 9 columns]
#
# Query 3:
#      Sno                                         Movie Name  \
# 0    433                                Mission: Impossible
# 1    434                                       Extraction 2
# 2    435                                          The Mummy
# 3    436                                       Man of Steel
# 4    437                                               Prey
# ..   ...                                                ...
# 489    5  The Lord of the Rings: The Fellowship of the Ring
# 490    6              The Lord of the Rings: The Two Towers
# 491    3                Spider-Man: Across the Spider-Verse
# 492    1                                    The Dark Knight
# 493    2      The Lord of the Rings: The Return of the King
#
#                   Director1    Director2           Director3 Duration  \
# 0            Brian De Palma         None                None  110 min
# 1              Sam Hargrave         None                None  122 min
# 2           Stephen Sommers         None                None  124 min
# 3               Zack Snyder         None                None  143 min
# 4          Dan Trachtenberg         None                None  100 min
# ..                      ...          ...                 ...      ...
# 489           Peter Jackson         None                None  178 min
# 490           Peter Jackson         None                None  179 min
# 491  s:\nJoaquim Dos Santos  Kemp Powers  Justin K. Thompson  140 min
# 492       Christopher Nolan         None                None  152 min
# 493           Peter Jackson         None                None  201 min
#
#          Year  Rating  Metascore
# 0        1996     7.1       59.0
# 1        2023     7.1       57.0
# 2        1999     7.1       48.0
# 3        2013     7.1       55.0
# 4    I) (2022     7.1       71.0
# ..        ...     ...        ...
# 489      2001     8.8       92.0
# 490      2002     8.8       87.0
# 491      2023     8.9       86.0
# 492      2008     9.0       84.0
# 493      2003     9.0       94.0
#
# [494 rows x 9 columns]
#
# Query 4:
#                       Movie Name
# 0                   Ölümlü Dünya
# 1                       Æon Flux
# 2        xXx: State of the Union
# 3     xXx: Return of Xander Cage
# 4                            xXx
# ...                          ...
# 1734                   12 Rounds
# 1735                   10,000 BC
# 1736             1 - Nenokkadine
# 1737                         '71
# 1738                   #Saraitda
#
# [1739 rows x 1 columns]
#
# Query 5:
#                                            Movie Name
# 0                                    Paan Singh Tomar
# 1   Pirates of the Caribbean: The Curse of the Bla...
# 2                             Per un pugno di dollari
# 3                                            Predator
# 4                                  Ponniyin Selvan: I
# 5                           Pushpa: The Rise - Part 1
# 6                                      Predestination
# 7          Pirates of the Caribbean: Dead Man's Chest
# 8                                        Patriots Day
# 9                                         Point Break
# 10                                               Prey
# 11           Pirates of the Caribbean: At World's End
# 12                                            Payback
#
# Query 6:
#                             Movie Name
# 0                       Batman & Robin
# 1                    Collateral Damage
# 2                             Commando
# 3                  Conan the Barbarian
# 4                  Conan the Destroyer
# 5                          End of Days
# 6                               Eraser
# 7                          Escape Plan
# 8                     Kindergarten Cop
# 9                     Last Action Hero
# 10                            Predator
# 11                            Raw Deal
# 12                            Red Heat
# 13                           Red Sonja
# 14                            Sabotage
# 15          Terminator 2: Judgment Day
# 16  Terminator 3: Rise of the Machines
# 17                  Terminator Genisys
# 18               Terminator: Dark Fate
# 19                         The 6th Day
# 20                      The Last Stand
# 21                     The Running Man
# 22                      The Terminator
# 23                        Total Recall
# 24                           True Lies
#
# Query 7:
#         Movie Name           Star1            Star2             Star3  \
# 0  The Dark Knight  Christian Bale   \nHeath Ledger   \nAaron Eckhart
#
#               Star4    Votes  Genre1 Genre2 Genre3 Gross collection  \
# 0   \nMichael Caine  2742002  Action  Crime  Drama         $534.86M
#
#   Popularity Certification
# 0         1.            UA
#
# Query 8:
#               Movie Name
# 0     Olympus Has Fallen
# 1       The Green Hornet
# 2       Inspector Gadget
# 3         Public Enemies
# 4        The Book of Eli
# ...                  ...
# 1734       The Prototype
# 1735               Radhe
# 1736   Angels Apocalypse
# 1737            Elk*rtuk
# 1738             Sadak 2
#
# [1739 rows x 1 columns]
#
# Query 9 :
#                             Movie Name Gross collection
# 0           Terminator 2: Judgment Day         $204.84M
# 1                       The Terminator          $38.40M
# 2                             Predator          $59.74M
# 3                         Total Recall         $119.39M
# 4                            True Lies         $146.28M
# 5                            The Mummy         $155.25M
# 6                  Conan the Barbarian          $39.57M
# 7                          Escape Plan          $25.13M
# 8                             Commando          $35.10M
# 9                      The Running Man          $38.12M
# 10                    Last Action Hero          $50.02M
# 11                   The Mummy Returns         $202.02M
# 12  Terminator 3: Rise of the Machines         $150.37M
# 13                  Terminator Genisys          $89.76M
# 14                      The Last Stand          $12.05M
# 15               Terminator: Dark Fate          $62.25M
# 16                    Kindergarten Cop          $91.46M
# 17                              Eraser         $101.30M
# 18                            Red Heat          $34.99M
# 19                 Conan the Destroyer          $31.04M
# 20                         The 6th Day          $34.60M
# 21                         End of Days          $66.89M
# 22                            Sabotage          $10.51M
# 23                            Raw Deal          $16.21M
# 24                   Collateral Damage          $40.08M
# 25                           Red Sonja           $6.95M
# 26                      Batman & Robin         $107.33M
#
# Query 10:
#                                       Movie Name           Star1  \
# 0                             Gangs of Wasseypur  Manoj Bajpayee
# 1                                   Sherlock Jr.   Buster Keaton
# 2                 Guardians of the Galaxy Vol. 3     Chris Pratt
# 3            Lock, Stock and Two Smoking Barrels   Jason Flemyng
# 4                              Bajrangi Bhaijaan     Salman Khan
# ..                                           ...             ...
# 367                 The Adventures of Pluto Nash    Eddie Murphy
# 368  The Adventures of Sharkboy and Lavagirl 3-D     Cayden Boyd
# 369        Spy Kids 4: All the Time in the World    Jessica Alba
# 370                                       Laxmii    Akshay Kumar
# 371                                  Heropanti 2    Tiger Shroff
#
#                       Star2                   Star3                 Star4  \
# 0     \nNawazuddin Siddiqui      \nTigmanshu Dhulia        \nRicha Chadha
# 1         \nKathryn McGuire            \nJoe Keaton      \nErwin Connelly
# 2          \nChukwudi Iwuji        \nBradley Cooper     \nPom Klementieff
# 3         \nDexter Fletcher            \nNick Moran       \nJason Statham
# 4      \nHarshaali Malhotra   \nNawazuddin Siddiqui      \nKareena Kapoor
# ..                      ...                     ...                   ...
# 367              \nJay Mohr           \nRandy Quaid      \nRosario Dawson
# 368          \nGeorge Lopez         \nKristin Davis      \nDavid Arquette
# 369          \nJeremy Piven           \nJoel McHale     \nRowan Blanchard
# 370          \nKiara Advani         \nSharad Kelkar    \nAshwini Kalsekar
# 371   \nNawazuddin Siddiqui          \nTara Sutaria   \nAmber Doig-Thorne
#
#       Votes  Genre1     Genre2   Genre3 Gross collection Popularity  \
# 0     99915  Action     Comedy    Crime             None        47.
# 1     53155  Action     Comedy  Romance           $0.98M        52.
# 2    221677  Action  Adventure   Comedy             None        59.
# 3    598142  Action     Comedy    Crime           $3.90M        69.
# 4     92713  Action  Adventure   Comedy           $8.18M        72.
# ..      ...     ...        ...      ...              ...        ...
# 367   26542  Action     Comedy   Sci-Fi           $4.42M     1,740.
# 368   40313  Action  Adventure   Comedy          $39.18M     1,744.
# 369   27180  Action  Adventure   Comedy          $38.54M     1,750.
# 370   58142  Action     Comedy   Horror             None     1,761.
# 371   27063  Action     Comedy    Crime             None     1,762.
#
#     Certification
# 0               A
# 1            None
# 2              UA
# 3               A
# 4              UA
# ..            ...
# 367         PG-13
# 368             U
# 369            PG
# 370        UA 16+
# 371            UA
#
# [372 rows x 12 columns]

# %%
# Subqueries

# Q11
query11 = """SELECT DISTINCT * FROM df1
JOIN df2 ON df1. `Movie Name` = df2. `Movie Name` """

result11 = pysqldf(query11)
print("Query 11:")
print(result11)
print()

# Q12
query12 = """SELECT DISTINCT df1. `Movie Name`, df1. Director1, df1. Director2, df1. Director3, df1. Rating, df2. `Gross collection`
FROM df1 JOIN df2 ON df1. `Movie Name` = df2. `Movie Name` 
WHERE df2. Genre1 LIKE '%Action%' OR df2. Genre2 LIKE '%Action%' OR df2. Genre3 LIKE '%Action%'"""

result12 = pysqldf(query12)
print("Query 12:")
print(result12)
print()

# Q13
query13 = """SELECT DISTINCT *
FROM df1
JOIN df2 ON df1. `Movie Name` = df2. `Movie Name`
WHERE df2. `Gross collection` = (SELECT MAX(`Gross collection`)FROM df2) """

result13 = pysqldf(query13)
print("Query 13:")
print(result13)
print()

# Q14
query14 = """SELECT DISTINCT * FROM df1
JOIN df2 ON df1. `Movie Name` = df2. `Movie Name`
WHERE df1. Rating = (SELECT MAX(Rating) FROM df1)"""

result14 = pysqldf(query14)
print("Query14:")
print(result14)
print()

# Q15
query15 = """SELECT DISTINCT * FROM df1
JOIN df2 ON df1. `Movie Name` = df2. `Movie Name`
WHERE df2. `Gross collection` = (SELECT MIN(`Gross collection`) FROM df2)
AND df1. Rating = (SELECT MIN(Rating)FROM df1)"""

result15 = pysqldf(query15)
print("Query 15:")
print(result15)
print()
# Out:
# Query 11:
#        Sno                                         Movie Name  \
# 0        1                                    The Dark Knight
# 1        2      The Lord of the Rings: The Return of the King
# 2        3                Spider-Man: Across the Spider-Verse
# 3        4                                          Inception
# 4        5  The Lord of the Rings: The Fellowship of the Ring
# ...    ...                                                ...
# 1827  1766                                              Radhe
# 1828  1767                                             Race 3
# 1829  1768                                  Angels Apocalypse
# 1830  1769                                           Elk*rtuk
# 1831  1770                                            Sadak 2
#
#                    Director1      Director2           Director3 Duration  \
# 0          Christopher Nolan           None                None  152 min
# 1              Peter Jackson           None                None  201 min
# 2     s:\nJoaquim Dos Santos    Kemp Powers  Justin K. Thompson  140 min
# 3          Christopher Nolan           None                None  148 min
# 4              Peter Jackson           None                None  178 min
# ...                      ...            ...                 ...      ...
# 1827             Prabhu Deva           None                None  109 min
# 1828            Remo D'Souza           None                None  160 min
# 1829           s:\nSean Cain  Enzo Zelocchi                None   85 min
# 1830           Keith English           None                None  125 min
# 1831            Mahesh Bhatt           None                None  133 min
#
#       Year  Rating  Metascore  \
# 0     2008     9.0       84.0
# 1     2003     9.0       94.0
# 2     2023     8.9       86.0
# 3     2010     8.8       74.0
# 4     2001     8.8       92.0
# ...    ...     ...        ...
# 1827  2021     1.9        NaN
# 1828  2018     1.9        NaN
# 1829  2015     1.6        NaN
# 1830  2021     1.5        NaN
# 1831  2020     1.2        NaN
#
#                                              Movie Name  ...  \
# 0                                       The Dark Knight  ...
# 1         The Lord of the Rings: The Return of the King  ...
# 2                   Spider-Man: Across the Spider-Verse  ...
# 3                                             Inception  ...
# 4     The Lord of the Rings: The Fellowship of the Ring  ...
# ...                                                 ...  ...
# 1827                                              Radhe  ...
# 1828                                             Race 3  ...
# 1829                                  Angels Apocalypse  ...
# 1830                                           Elk*rtuk  ...
# 1831                                            Sadak 2  ...
#
#                         Star2                 Star3                    Star4  \
# 0              \nHeath Ledger       \nAaron Eckhart          \nMichael Caine
# 1           \nViggo Mortensen        \nIan McKellen          \nOrlando Bloom
# 2          \nHailee Steinfeld   \nBrian Tyree Henry      \nLuna Lauren Velez
# 3      \nJoseph Gordon-Levitt         \nElliot Page           \nKen Watanabe
# 4              \nIan McKellen       \nOrlando Bloom              \nSean Bean
# ...                       ...                   ...                      ...
# 1827           \nDisha Patani       \nRandeep Hooda          \nJackie Shroff
# 1828            \nSalman Khan          \nBobby Deol   \nJacqueline Fernandez
# 1829          \nJana Rochelle   \nRyan C.F. Buckley        \nWilliam Kirkham
# 1830           \nAndrás Mózes         \nBarna Bokor        \nGabriella Gubás
# 1831            \nPooja Bhatt   \nAditya Roy Kapoor            \nSanjay Dutt
#
#         Votes     Genre1     Genre2     Genre3 Gross collection Popularity  \
# 0     2742002     Action      Crime      Drama         $534.86M         1.
# 1     1899372     Action  Adventure      Drama         $377.85M         2.
# 2      186672  Animation     Action  Adventure             None         3.
# 3     2433238     Action  Adventure     Sci-Fi         $292.58M         4.
# 4     1927794     Action  Adventure      Drama         $315.54M         5.
# ...       ...        ...        ...        ...              ...        ...
# 1827   179060     Action      Crime   Thriller             None     1,766.
# 1828    47815     Action      Crime   Thriller           $1.69M     1,767.
# 1829    42919     Action    Fantasy     Sci-Fi             None     1,768.
# 1830    39601     Action      Crime      Drama             None     1,769.
# 1831    96354     Action      Drama       None             None     1,770.
#
#      Certification
# 0               UA
# 1                U
# 2                U
# 3               UA
# 4                U
# ...            ...
# 1827            UA
# 1828            UA
# 1829          None
# 1830          None
# 1831           15+
#
# [1832 rows x 21 columns]
#
# Query 12:
#                                              Movie Name  \
# 0                                       The Dark Knight
# 1         The Lord of the Rings: The Return of the King
# 2                   Spider-Man: Across the Spider-Verse
# 3                                             Inception
# 4     The Lord of the Rings: The Fellowship of the Ring
# ...                                                 ...
# 1827                                              Radhe
# 1828                                             Race 3
# 1829                                  Angels Apocalypse
# 1830                                           Elk*rtuk
# 1831                                            Sadak 2
#
#                    Director1      Director2           Director3  Rating  \
# 0          Christopher Nolan           None                None     9.0
# 1              Peter Jackson           None                None     9.0
# 2     s:\nJoaquim Dos Santos    Kemp Powers  Justin K. Thompson     8.9
# 3          Christopher Nolan           None                None     8.8
# 4              Peter Jackson           None                None     8.8
# ...                      ...            ...                 ...     ...
# 1827             Prabhu Deva           None                None     1.9
# 1828            Remo D'Souza           None                None     1.9
# 1829           s:\nSean Cain  Enzo Zelocchi                None     1.6
# 1830           Keith English           None                None     1.5
# 1831            Mahesh Bhatt           None                None     1.2
#
#      Gross collection
# 0            $534.86M
# 1            $377.85M
# 2                None
# 3            $292.58M
# 4            $315.54M
# ...               ...
# 1827             None
# 1828           $1.69M
# 1829             None
# 1830             None
# 1831             None
#
# [1832 rows x 6 columns]
#
# Query 13:
#    Sno          Movie Name      Director1 Director2 Director3 Duration  Year  \
# 0  868  Olympus Has Fallen  Antoine Fuqua      None      None  119 min  2013
#
#    Rating  Metascore          Movie Name  ...             Star2  \
# 0     6.5       41.0  Olympus Has Fallen  ...   \nAaron Eckhart
#
#                Star3              Star4   Votes  Genre1    Genre2 Genre3  \
# 0   \nMorgan Freeman   \nAngela Bassett  284975  Action  Thriller   None
#
#   Gross collection Popularity Certification
# 0          $98.93M       868.             A
#
# [1 rows x 21 columns]
#
# Query14:
#    Sno                                     Movie Name          Director1  \
# 0    1                                The Dark Knight  Christopher Nolan
# 1    2  The Lord of the Rings: The Return of the King      Peter Jackson
#
#   Director2 Director3 Duration  Year  Rating  Metascore  \
# 0      None      None  152 min  2008     9.0       84.0
# 1      None      None  201 min  2003     9.0       94.0
#
#                                       Movie Name  ...               Star2  \
# 0                                The Dark Knight  ...      \nHeath Ledger
# 1  The Lord of the Rings: The Return of the King  ...   \nViggo Mortensen
#
#               Star3             Star4    Votes  Genre1     Genre2 Genre3  \
# 0   \nAaron Eckhart   \nMichael Caine  2742002  Action      Crime  Drama
# 1    \nIan McKellen   \nOrlando Bloom  1899372  Action  Adventure  Drama
#
#   Gross collection Popularity Certification
# 0         $534.86M         1.            UA
# 1         $377.85M         2.             U
#
# [2 rows x 21 columns]
#
# Query 15:
# Empty DataFrame
# Columns: [Sno, Movie Name, Director1, Director2, Director3, Duration, Year, Rating, Metascore, Movie Name, Star1, Star2, Star3, Star4, Votes, Genre1, Genre2, Genre3, Gross collection, Popularity, Certification]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Here All queries and subqueries are sorted using Pandasql.
